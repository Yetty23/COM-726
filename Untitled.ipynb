# %%
from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.enum.text import PP_ALIGN
from pptx.dml.color import RGBColor
import shutil

# Provide the correct path to the file
shutil.move("Heart_Failure_Readmission_Prediction_Presentation.pptx", "Heart_Failure_Presentation.pptx")

"Heart_Failure_Presentation.pptx"


# Create a presentation object
presentation = Presentation()

# Slide 1: Title and Objectives
slide_1 = presentation.slides.add_slide(presentation.slide_layouts[0])
title_1 = slide_1.shapes.title
subtitle_1 = slide_1.placeholders[1]

title_1.text = "Heart Failure Readmission Prediction Using Machine Learning"
subtitle_1.text = "Developing a Predictive Model and Deploying a Web Application\n[Your Name]\n[Date of Presentation]"

# Slide 2: Background and Motivation
slide_2 = presentation.slides.add_slide(presentation.slide_layouts[1])
title_2 = slide_2.shapes.title
title_2.text = "Background and Motivation"

content_2 = slide_2.shapes.placeholders[1].text_frame
content_2.text = ("Heart failure is a leading cause of hospital readmissions, placing a significant burden on patients and healthcare systems. "
                  "Early identification of patients at risk of readmission can improve patient outcomes and reduce healthcare costs. "
                  "This project addresses the gap in predictive tools available for clinicians by leveraging machine learning techniques.")

# Slide 3: Data Collection and Preprocessing
slide_3 = presentation.slides.add_slide(presentation.slide_layouts[1])
title_3 = slide_3.shapes.title
title_3.text = "Data Collection and Preprocessing"

content_3 = slide_3.shapes.placeholders[1].text_frame
content_3.text = ("Data was collected from [Dataset Source], comprising [Number] patient records with features such as age, ejection fraction, serum creatinine levels, etc.\n"
                  "Preprocessing steps included handling missing values, normalizing continuous variables, and selecting relevant features.")

# Slide 4: Model Development
slide_4 = presentation.slides.add_slide(presentation.slide_layouts[1])
title_4 = slide_4.shapes.title
title_4.text = "Model Development"

content_4 = slide_4.shapes.placeholders[1].text_frame
content_4.text = ("Multiple machine learning models were developed, including Logistic Regression, Random Forest, Gradient Boosting, and Neural Networks. "
                  "Model selection was based on their ability to handle structured clinical data and provide interpretability.")

# Slide 5: Application Development
slide_5 = presentation.slides.add_slide(presentation.slide_layouts[1])
title_5 = slide_5.shapes.title
title_5.text = "Application Development"

content_5 = slide_5.shapes.placeholders[1].text_frame
content_5.text = ("The predictive model was deployed using Streamlit, a Python framework that enables the creation of interactive web applications. "
                  "The application allows healthcare professionals to input patient data and receive a prediction of readmission risk.")

# Slide 6: Results and Analysis
slide_6 = presentation.slides.add_slide(presentation.slide_layouts[1])
title_6 = slide_6.shapes.title
title_6.text = "Results and Analysis"

content_6 = slide_6.shapes.placeholders[1].text_frame
content_6.text = ("The Random Forest model outperformed other models with an accuracy of X% and an AUC-ROC score of Y. "
                  "Key predictors identified include age, serum creatinine, and ejection fraction.")

# Slide 7: Conclusion and Future Work
slide_7 = presentation.slides.add_slide(presentation.slide_layouts[1])
title_7 = slide_7.shapes.title
title_7.text = "Conclusion and Future Work"

content_7 = slide_7.shapes.placeholders[1].text_frame
content_7.text = ("The developed model and application provide a practical tool for predicting heart failure readmissions, with potential to improve clinical decision-making. "
                  "Future work includes testing the application in a clinical setting and refining the model with additional data.")

# Slide 8: Thank You and Questions
slide_8 = presentation.slides.add_slide(presentation.slide_layouts[1])
title_8 = slide_8.shapes.title
title_8.text = "Thank You"

content_8 = slide_8.shapes.placeholders[1].text_frame
content_8.text = ("Thank you for your attention. I’m happy to take any questions.\n\n[Your Contact Information]")

# Save the presentation
presentation.save("Heart_Failure_Readmission_Prediction_Presentation.pptx")

"Heart_Failure_Readmission_Prediction_Presentation.pptx"
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\Lib\shutil.py:825, in move(src, dst, copy_function)
#     824 try:
# --> 825     os.rename(src, real_dst)
#     826 except OSError:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'Heart_Failure_Readmission_Prediction_Presentation.pptx' -> 'Heart_Failure_Presentation.pptx'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       5 import shutil
#       7 # Provide the correct path to the file
# ----> 8 shutil.move("Heart_Failure_Readmission_Prediction_Presentation.pptx", "Heart_Failure_Presentation.pptx")
#      10 "Heart_Failure_Presentation.pptx"
#      13 # Create a presentation object
#
# File ~\anaconda3\Lib\shutil.py:845, in move(src, dst, copy_function)
# ...

# %%
from pptx import Presentation
from pptx.util import Inches, Pt

# Create a presentation object
prs = Presentation()

# Slide 1: Title and Objectives
slide1 = prs.slides.add_slide(prs.slide_layouts[0])
title1 = slide1.shapes.title
subtitle1 = slide1.placeholders[1]
title1.text = "Heart Failure Readmission Prediction"
subtitle1.text = "A Machine Learning Approach"

# Add content to Slide 1
slide1_content = slide1.shapes.add_textbox(Inches(1), Inches(1.5), Inches(8), Inches(2))
slide1_text_frame = slide1_content.text_frame
slide1_text_frame.text = "Objectives of the Dissertation:"
p = slide1_text_frame.add_paragraph()
p.text = "• Develop a predictive model for heart failure readmission."
p.level = 1
p = slide1_text_frame.add_paragraph()
p.text = "• Deploy the model in a user-friendly web application."
p.level = 1

# Save the presentation
prs.save('Heart_Failure_Presentation.pptx')
